# %% [markdown]
# # **EV Charging Infrastructure Analysis**
#
# This notebook is responsible for loading the dataset and performing an initial inspection of its structure and contents.
#
# ## Objectives
#
# - Load the raw dataset.
# - Verify that the data was loaded correctly.
# - Understand the dataset dimensions.
# - Inspect the first and last records.
# - Identify column names and data types.
# - Perform an initial assessment of the dataset.
#
# ---
#
# ## 1. Project Context
#
# The global adoption of electric vehicles (EVs) has increased the importance of charging infrastructure, market adoption, vehicle characteristics, and government incentives.
#
# This project analyzes data related to electric vehicles and charging infrastructure across different countries and regions.
#
# The analysis will investigate relationships between EV sales, charging infrastructure, vehicle characteristics, market adoption, government incentives, and environmental impact.
#
# The dataset will also be evaluated to determine whether it can support predictive Machine Learning models.

# %% [markdown]
# ## 2. Libraries
#
# The libraries below will be used for data manipulation and initial analysis.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 3. Dataset Path
#
# The raw dataset is stored in the `data/raw/` directory.

# %%
DATA_PATH = "../data/raw/global_ev_market_charging_infrastructure_2026.csv"

# %% [markdown]
# ## 4. Load Dataset
#
# The dataset will be loaded using Pandas' `read_csv()` function.

# %%
# Load dataset
df = pd.read_csv(DATA_PATH)

# %%
# Dataset dimensions
rows, columns = df.shape

print(f"Number of rows: {rows:,}")
print(f"Number of columns: {columns}")
# Out:
# Number of rows: 5,000
# Number of columns: 16

# %%
# First observations
display(df.head())
display(df.tail())
# Out:
#   record_id    country         region  ev_brand vehicle_type  ev_sales_units  \
# 0    EV0001      China           Asia  Mercedes          Bus          459155
# 1    EV0002     Canada  North America   Hyundai          Car          722074
# 2    EV0003  Australia        Oceania      Ford          Bus          241638
# 3    EV0004      China           Asia    Toyota          Car          681021
# 4    EV0005     Canada  North America      Ford          SUV          714686
#
#    battery_capacity_kwh  vehicle_range_km  charging_time_hours  \
# 0                    42               285                 1.21
# 1                    50               330                 0.52
# 2                   105               483                 2.41
# 3                   116               472                 1.53
# 4                   114               485                 2.07
#
#    charging_stations  avg_ev_price_usd  energy_consumption_kwh  \
# ...

# %%
# Data types
print("Data Types:\n")
display(df.dtypes.to_frame(name="Data Type"))
# Out:
# Data Types:
#                        Data Type
# record_id                    str
# country                      str
# region                       str
# ev_brand                     str
# vehicle_type                 str
# ev_sales_units             int64
# battery_capacity_kwh       int64
# vehicle_range_km           int64
# charging_time_hours      float64
# charging_stations          int64
# avg_ev_price_usd           int64
# energy_consumption_kwh   float64
# govt_incentives              str
# market_adoption_rate     float64
# co2_reduction_mt         float64
# year                       int64

# %%
# General information
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   record_id               5000 non-null   str
#  1   country                 5000 non-null   str
#  2   region                  5000 non-null   str
#  3   ev_brand                5000 non-null   str
#  4   vehicle_type            5000 non-null   str
#  5   ev_sales_units          5000 non-null   int64
#  6   battery_capacity_kwh    5000 non-null   int64
#  7   vehicle_range_km        5000 non-null   int64
#  8   charging_time_hours     5000 non-null   float64
#  9   charging_stations       5000 non-null   int64
#  10  avg_ev_price_usd        5000 non-null   int64
#  11  energy_consumption_kwh  5000 non-null   float64
#  12  govt_incentives         5000 non-null   str
#  13  market_adoption_rate    5000 non-null   float64
#  14  co2_reduction_mt        5000 non-null   float64
# ...

# %%
# Descriptive statistics
display(df.describe().T)
# Out:
#                          count           mean            std      min  \
# ev_sales_units          5000.0  450391.774000  258494.794603   5142.0
# battery_capacity_kwh    5000.0      79.753800      23.474791     40.0
# vehicle_range_km        5000.0     450.278000     116.325407    250.0
# charging_time_hours     5000.0       1.742614       0.719029      0.5
# charging_stations       5000.0  100851.553400   56905.671677    574.0
# avg_ev_price_usd        5000.0   55633.191800   17289.560508  25000.0
# energy_consumption_kwh  5000.0      18.527740       3.749015     12.0
# market_adoption_rate    5000.0      34.848660      17.276752      5.0
# co2_reduction_mt        5000.0     153.196280      84.829245      5.1
# year                    5000.0    2026.000000       0.000000   2026.0
#
#                               25%        50%         75%       max
# ev_sales_units          224814.00  455096.50  673542.000  899978.0
# ...

# %% [markdown]
# ## 7. Initial Observations
#
# The dataset contains 5,000 records and 16 variables related to electric vehicle markets and charging infrastructure.
#
# The variables cover several dimensions of the EV ecosystem, including:
#
# - Geographic information;
# - Vehicle characteristics;
# - EV sales;
# - Charging infrastructure;
# - Market adoption;
# - Government incentives;
# - Environmental impact.
#
# At this stage, the dataset has only been loaded and initially inspected. No data cleaning or transformation decisions have been made yet.
#
# A more detailed assessment of data quality will be performed in the Data Audit stage.
